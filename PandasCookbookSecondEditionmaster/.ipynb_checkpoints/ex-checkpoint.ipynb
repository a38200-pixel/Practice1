# %%
import pandas as pd
import numpy as np
movies = pd.read_csv("data/movie.csv")
print(movies.director_name.isna())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool
