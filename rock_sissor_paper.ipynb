# %% [markdown]
# <a href="https://colab.research.google.com/github/a38200-pixel/Practice1/blob/main/rock_sissor_paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
user_win = 0
com_win = 0
choices = ["가위", "바위", "보"]


def check_winner(user, com):
    result = (user - com + 3) % 3

    if result == 0:
        return "무승부"
    elif result == 1:
        return "승리"
    else:
        return "패배"
print("5전 3승 가위바위보 게임")

while user_win <3 and com_win <3:
    user_input= input("가위, 바위, 보 중 하나를 입력하세요.")
    if user_input not in choices:
        print("잘못된 입력입니다. 다시 선택해주세요.")
        continue
    user = choices.index(user_input)
    com = random.randint(0, 2)
    com_input = choices[com]

    판정 = check_winner(user, com)

            #승리 횟수 누적
    if 판정 == '승리':
        user_win = user_win + 1
        print(f"사용자가 승리했어요(사용자 승리횟수: {user_win})")
    elif 판정 == '패배':
        com_win = com_win + 1
        print(f"컴퓨터가 승리했어요(컴퓨터 승리횟수: {com_win})")
    else:
        print("무승부 입니다")

if user_win == 3:
    print("축하합니다. 우승입니다.")
else:
    print("아쉽습니다. 다시 도전하세요")
# Out:
# 5전 3승 가위바위보 게임
# 가위, 바위, 보 중 하나를 입력하세요.가위
# 사용자가 승리했어요(사용자 승리횟수: 1)
# 가위, 바위, 보 중 하나를 입력하세요.바뷔
# 잘못된 입력입니다. 다시 선택해주세요.
# 가위, 바위, 보 중 하나를 입력하세요.바위
# 무승부 입니다
# 가위, 바위, 보 중 하나를 입력하세요.보
# 컴퓨터가 승리했어요(컴퓨터 승리횟수: 1)
# 가위, 바위, 보 중 하나를 입력하세요.보
# 컴퓨터가 승리했어요(컴퓨터 승리횟수: 2)
# 가위, 바위, 보 중 하나를 입력하세요.보
# 컴퓨터가 승리했어요(컴퓨터 승리횟수: 3)
# 아쉽습니다. 다시 도전하세요

# %%
def check_winner(user, com):
    result = (user - com + 3) % 3

    if result == 0:
        return "무승부"
    elif result == 1:
        return "승리"
    else:
        return "패배"
